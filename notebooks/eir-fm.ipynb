# %% [markdown]
# # Introduction

# %% [markdown]
# Introduction text / cells go here...

# %%
import sys
sys.executable
# Out:
# '/Users/hrv220/git/integrative_post_gwas_methods_course/.venv/bin/python3'

# %% [markdown]
# # Data setup

# %%
import gdown

# %%
model_zip_id = "1hRnULP7o8nOdWUzp4uJQcqnKZakuFJ3W"
output = "../reference_data/models"
gdown.download(id=model_zip_id, output=output)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1hRnULP7o8nOdWUzp4uJQcqnKZakuFJ3W
# From (redirected): https://drive.google.com/uc?id=1hRnULP7o8nOdWUzp4uJQcqnKZakuFJ3W&confirm=t&uuid=3056ce31-1a37-45ca-96e4-d4ca842f2ae0
# To: /Users/hrv220/git/integrative_post_gwas_methods_course/reference_data/models
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1.53G/1.53G [01:31<00:00, 16.7MB/s]
# '../reference_data/models'

# %%
human_origins_id = "1biAqQMw6jYCmEWc7OjdCxHR8gorHOqEW"
output = "../reference_data/"
gdown.download(id=human_origins_id, output=output)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1biAqQMw6jYCmEWc7OjdCxHR8gorHOqEW
# From (redirected): https://drive.google.com/uc?id=1biAqQMw6jYCmEWc7OjdCxHR8gorHOqEW&confirm=t&uuid=747fc59f-09c0-4241-8f92-45d1e78c7f57
# To: /Users/hrv220/git/integrative_post_gwas_methods_course/reference_data/human_origins.zip
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 122M/122M [00:07<00:00, 17.0MB/s]
# '../reference_data/human_origins.zip'

# %%
# !unzip -o ../reference_data/human_origins.zip -d ../reference_data

# %% [markdown]
# # Prediction

# %%
# !eirautogppredict --genotype_data_path ../reference_data/human_origins --packed_experiment_path ../reference_data/models/ext_d_inf_moe_general_16L-FUS_multitask.zip --output_folder ../output
# Out:
# Traceback (most recent call last):
#   File "/Users/hrv220/git/integrative_post_gwas_methods_course/.venv/bin/eirautogppredict", line 10, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "/Users/hrv220/git/integrative_post_gwas_methods_course/.venv/lib/python3.13/site-packages/eir_auto_gp/predict/run_predict.py", line 609, in main
#     run_sync_and_predict_wrapper(cl_args=cl_args)
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#   File "/Users/hrv220/git/integrative_post_gwas_methods_course/.venv/lib/python3.13/site-packages/eir_auto_gp/predict/run_predict.py", line 86, in run_sync_and_predict_wrapper
#     unpacked_experiment_path = unpack_experiment(
#         packed_experiment_path=cl_args.packed_experiment_path,
#         output_path=cl_args.output_folder + "/unpacked_experiment",
#     )
#   File "/Users/hrv220/git/integrative_post_gwas_methods_course/.venv/lib/python3.13/site-packages/eir_auto_gp/predict/pack.py", line 180, in unpack_experiment
#     with zipfile.ZipFile(packed_experiment_path, "r") as zipf:
#          ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/hrv220/miniconda3/lib/python3.13/zipfile/__init__.py", line 1367, in __init__
#     self.fp = io.open(file, filemode)
#               ~~~~~~~^^^^^^^^^^^^^^^^
# NotADirectoryError: [Errno 20] Not a directory: '../reference_data/models/ext_d_inf_moe_general_16L-FUS_multitask.zip'

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Imports and setup

# %%
from pathlib import Path
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

RESULTS_DIR = Path("../output/results")
LABELS_PATH = Path("../reference_data/human_origins/human_origins_labels.csv")

# %%
def load_trait_csv(path: Path) -> pd.Series:
  df = pd.read_csv(path).set_index("ID")
  trait = path.stem
  prob1 = [c for c in df.columns if c.endswith("Ensemble Prob 1")]
  if prob1:
      s = df[prob1[0]].rename(trait)
      s.attrs["kind"] = "binary"
      return s
  ensemble = [c for c in df.columns if re.fullmatch(rf"{re.escape(trait)} Ensemble", c)]
  if not ensemble:
      raise ValueError(f"No ensemble column found in {path.name}: {list(df.columns)}")
  s = df[ensemble[0]].rename(trait)
  s.attrs["kind"] = "continuous"
  return s

# %% [markdown]
# ## Loading in the predictions

# %%
series_list, kinds = [], {}
for p in sorted(RESULTS_DIR.glob("*.csv")):
  s = load_trait_csv(p)
  series_list.append(s)
  kinds[s.name] = s.attrs["kind"]

preds = pd.concat(series_list, axis=1)
trait_kind = pd.Series(kinds, name="kind")
print(f"preds: {preds.shape}  continuous={(trait_kind=='continuous').sum()}  binary={(trait_kind=='binary').sum()}")
preds.head()
# Out:
# preds: (1963, 315)  continuous=237  binary=78
#           Alanine_aminotransferase  Albumin_BIOCH  Alkaline_phosphatase  \
# ID
# ADR00057                 26.459091      45.228622              88.01055
# ADR00059                 25.945532      45.510212              88.43760
# ADR00060                 23.012245      45.072610             100.55502
# ADR00061                 25.830112      45.074306              86.74373
# ADR00064                 24.785912      45.463715              80.79481
#
#           Apolipoprotein_A  Apolipoprotein_A1  Apolipoprotein_B_BIOCH  \
# ID
# ADR00057          1.552347           1.488011                1.045121
# ADR00059          1.641881           1.557267                1.006566
# ADR00060          1.566644           1.503591                1.023278
# ADR00061          1.522103           1.465549                1.063156
# ADR00064          1.618582           1.543648                1.022996
#
#           Apolipoprotein_B_METAB  Aspartate_aminotransferase  \
# ID
# ADR00057                0.874985                   26.829440
# ADR00059                0.844887                   25.655012
# ADR00060                0.843186                   25.577772
# ADR00061                0.870965                   26.178743
# ADR00064                0.848231                   26.008583
#
#           Average_Diameter_for_HDL_Particles  \
# ID
# ADR00057                            9.589702
# ADR00059                            9.625848
# ADR00060                            9.583400
# ADR00061                            9.567302
# ADR00064                            9.634799
#
#           Average_Diameter_for_VLDL_Particles  ...      Urea  \
# ID                                             ...
# ADR00057                            38.743828  ...  5.266588
# ADR00059                            39.020460  ...  5.303911
# ADR00060                            38.623573  ...  5.237378
# ADR00061                            39.081078  ...  5.308926
# ADR00064                            38.626990  ...  5.475279
#
#           VLDL_Cholesterol  Vitamin_D  Waist_circumference  Weight_ANTHRO  \
# ID
# ADR00057          0.741728  49.203700            88.304940       76.49536
# ADR00059          0.715058  52.251730            89.971190       78.22484
# ADR00060          0.695017  52.643284            88.132490       75.98319
# ADR00061          0.755620  52.331310            89.216835       75.90028
# ADR00064          0.701150  49.692510            87.144020       71.74880
#
#           Weight_IMPED  White_blood_cell_leukocyte_count  \
# ID
# ADR00057     76.374580                          6.756397
# ADR00059     78.287480                          7.038601
# ADR00060     76.195750                          6.870369
# ADR00061     75.968830                          7.446775
# ADR00064     71.760254                          6.803563
#
#           Whole_body_fat_free_mass  Whole_body_fat_mass  Whole_body_water_mass
# ID
# ADR00057                 51.706840            23.084438              37.683327
# ADR00059                 53.165154            23.861643              39.013410
# ADR00060                 52.112446            24.026302              38.096157
# ADR00061                 52.148335            23.279701              38.183080
# ADR00064                 50.201290            22.231268              36.685974
#
# [5 rows x 315 columns]

# %% [markdown]
# ## Merge labels with ancestry

# %%
labels = pd.read_csv(LABELS_PATH).set_index("ID")
df = preds.join(labels, how="inner")
print(f"merged: {df.shape}  unique ancestries: {df['Origin'].nunique()}")
df["Origin"].value_counts()
# Out:
# merged: (1891, 316)  unique ancestries: 6
# Origin
# Europe                             708
# Middle_East                        364
# Asia                               280
# Eastern_Asia                       223
# Sub-Saharan_Africa                 218
# Latin_America_and_the_Caribbean     98
# Name: count, dtype: int64

# %% [markdown]
# ## Clustering correlated traits

# %%
cont_traits = trait_kind.index[trait_kind == "continuous"].tolist()
cont = df[cont_traits].apply(pd.to_numeric, errors="coerce")
cont = cont.loc[:, cont.std() > 0]
corr = cont.corr(method="spearman")

order = sns.clustermap(corr, cmap="vlag", center=0, figsize=(14, 14),
                    xticklabels=False, yticklabels=False).dendrogram_row.reordered_ind
plt.show()
print(f"Continuous traits in correlation: {corr.shape[0]}")
# Out:
# Continuous traits in correlation: 237

# %%
mask = np.triu(np.ones(corr.shape, dtype=bool), k=1)
pairs = (corr.where(mask).stack()
            .rename("spearman").reset_index()
            .rename(columns={"level_0": "trait_a", "level_1": "trait_b"}))
pairs["abs_r"] = pairs["spearman"].abs()
pairs.sort_values("abs_r", ascending=False).head(20)
# Out:
#                                           trait_a  \
# 4328                     Cholesterol_in_Large_HDL
# 27951                               Weight_ANTHRO
# 24767             Phospholipids_in_Very_Large_HDL
# 6246                Cholesterol_in_Very_Large_HDL
# 11445        Concentration_of_Large_HDL_Particles
# 2766                   Body_mass_index_BMI_ANTHRO
# 23911                  Phospholipids_in_Large_HDL
# 13564  Concentration_of_Very_Small_VLDL_Particles
# 4976                    Cholesterol_in_Medium_HDL
# 12874       Concentration_of_Small_VLDL_Particles
# 11347        Concentration_of_Large_HDL_Particles
# 4347                     Cholesterol_in_Large_HDL
# 24926            Phospholipids_in_Very_Small_VLDL
# 4753                    Cholesterol_in_Large_VLDL
# 4480                     Cholesterol_in_Large_HDL
# 6399                Cholesterol_in_Very_Large_HDL
# 4382                     Cholesterol_in_Large_HDL
# 18706         Free_Cholesterol_in_Very_Large_VLDL
# 17185               Free_Cholesterol_in_Large_HDL
# 11404        Concentration_of_Large_HDL_Particles
#
#                                     trait_b  spearman     abs_r
# 4328        Cholesteryl_Esters_in_Large_HDL  0.996693  0.996693
# 27951                          Weight_IMPED  0.995728  0.995728
# 24767        Total_Lipids_in_Very_Large_HDL  0.995723  0.995723
# 6246   Cholesteryl_Esters_in_Very_Large_HDL  0.995678  0.995678
# 11445             Total_Lipids_in_Large_HDL  0.995634  0.995634
# 2766              Body_mass_index_BMI_IMPED  0.995487  0.995487
# 23911             Total_Lipids_in_Large_HDL  0.995216  0.995216
# 13564       Total_Lipids_in_Very_Small_VLDL  0.994615  0.994615
# 4976       Cholesteryl_Esters_in_Medium_HDL  0.994582  0.994582
# 12874            Total_Lipids_in_Small_VLDL  0.994520  0.994520
# 11347         Free_Cholesterol_in_Large_HDL  0.993916  0.993916
# 4347   Concentration_of_Large_HDL_Particles  0.993877  0.993877
# 24926       Total_Lipids_in_Very_Small_VLDL  0.993868  0.993868
# 4753         Cholesterol_in_Very_Large_VLDL  0.993854  0.993854
# 4480              Total_Lipids_in_Large_HDL  0.993625  0.993625
# 6399         Total_Lipids_in_Very_Large_HDL  0.993367  0.993367
# 4382          Free_Cholesterol_in_Large_HDL  0.993040  0.993040
# 18706      Phospholipids_in_Very_Large_VLDL  0.992947  0.992947
# 17185             Total_Lipids_in_Large_HDL  0.992935  0.992935
# 11404            Phospholipids_in_Large_HDL  0.992695  0.992695

# %% [markdown]
# ## Cluster visualization

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from itertools import combinations
import matplotlib.lines as mlines

X_df = df[cont.columns].dropna(axis=1, thresh=int(0.95 * len(df)))
X = StandardScaler().fit_transform(X_df.values)

origins = (df.loc[X_df.index, "Origin"]
           .value_counts().index.tolist()) 
palette = dict(zip(origins, sns.color_palette("tab10", n_colors=len(origins))))

pca = PCA(n_components=4, random_state=0)
pcs = pca.fit_transform(X)
pc_df = pd.DataFrame(pcs, columns=[f"PC{i+1}" for i in range(4)], index=X_df.index)
pc_df["Origin"] = df.loc[X_df.index, "Origin"]

pairs = list(combinations(range(1, 5), 2))
fig, axes = plt.subplots(2, 3, figsize=(16, 10))
for ax, (i, j) in zip(axes.flat, pairs):
  for origin in origins:
      sub = pc_df[pc_df["Origin"] == origin]
      ax.scatter(sub[f"PC{i}"], sub[f"PC{j}"],
                 s=18, alpha=0.7, linewidth=0.3,
                 edgecolor="white", color=palette[origin], label=origin)
  var_i, var_j = pca.explained_variance_ratio_[i-1], pca.explained_variance_ratio_[j-1]
  ax.set_xlabel(f"PC{i} ({var_i*100:.1f}%)")
  ax.set_ylabel(f"PC{j} ({var_j*100:.1f}%)")
  ax.spines[["top", "right"]].set_visible(False)
  ax.grid(alpha=0.2)

handles = [mlines.Line2D([], [], marker="o", linestyle="",
                       markersize=8, markerfacecolor=palette[o],
                       markeredgecolor="white", markeredgewidth=0.5, label=o)
         for o in origins]
fig.legend(handles=handles, bbox_to_anchor=(1.0, 0.5), loc="center left",
         frameon=False, title="Origin")
fig.suptitle(f"PCA of {X_df.shape[1]} continuous-trait predictions  (n={len(pc_df)})",
           fontsize=13)
plt.tight_layout(rect=[0, 0, 0.92, 0.97])
plt.show()

# %%
import umap

reducer = umap.UMAP(n_components=4, n_neighbors=30, min_dist=0.3,
                  metric="euclidean", random_state=0, n_jobs=1)
emb = reducer.fit_transform(X)
um_df = pd.DataFrame(emb, columns=[f"UMAP{i+1}" for i in range(4)], index=X_df.index)
um_df["Origin"] = df.loc[X_df.index, "Origin"]

fig, axes = plt.subplots(2, 3, figsize=(16, 10))
for ax, (i, j) in zip(axes.flat, pairs):
  for origin in origins:
      sub = um_df[um_df["Origin"] == origin]
      ax.scatter(sub[f"UMAP{i}"], sub[f"UMAP{j}"],
                 s=18, alpha=0.7, linewidth=0.3,
                 edgecolor="white", color=palette[origin], label=origin)
  ax.set_xlabel(f"UMAP{i}"); ax.set_ylabel(f"UMAP{j}")
  ax.spines[["top", "right"]].set_visible(False)
  ax.grid(alpha=0.2)

fig.legend(handles=handles, bbox_to_anchor=(1.0, 0.5), loc="center left",
         frameon=False, title="Origin")
fig.suptitle(f"UMAP of {X_df.shape[1]} continuous-trait predictions  (n={len(um_df)})",
           fontsize=13)
plt.tight_layout(rect=[0, 0, 0.92, 0.97])
plt.show()
